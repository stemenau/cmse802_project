# %% [markdown]
# This notebook implements the random forest regression model outlined in Random_Forest.py.

# %%
# Import necessary packages
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
import shap
import sys
from pathlib import Path

# Import add_docking_scores function
project_root = Path.cwd().parents[0]  # goes up one levels: notebooks -> cmse802_project
sys.path.append(str(project_root))
import src.Gradient_Boost as gb

# Initialize model with data path
data_path = '../data/data_final.csv'
gb_model = gb.GradientBoostModel(data_path)

# Load and preprocess data
gb_model.load_and_preprocess_data()

# Train the model
gb_model.train_model()

# Evaluate the model
gb_model.evaluate_model()

# Plot results
gb_model.plot_results()

# Explain model predictions
gb_model.explain_model()
# Out:
# Mean Squared Error: 0.2219167541842457
# R² Score: 0.90948707634829
