# %% [markdown]
# This notebook serves to perform exploratory data analysis (EDA), generating visualizations of data distributions and relationships.

# %%
# Import necessary packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys
from pathlib import Path

# Import add_docking_scores function
project_root = Path.cwd().parents[0]  # goes up one level: notebooks -> cmse802_project
sys.path.append(str(project_root))
from src.EDA import load_data, plot_histograms, plot_pairplots, plot_spearman_correlation

data = load_data('../data/data_final.csv')
plot_histograms(data)
plot_pairplots(data)
plot_spearman_correlation(data)
